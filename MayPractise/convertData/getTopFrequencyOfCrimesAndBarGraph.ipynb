# %%
#import pickle data
import pickle
file = open("data1000.obj", 'rb')
df = pickle.load(file)
file.close()

# %%
# count frequency the basis of Primary type column
df['Primary Type'].value_counts()
# Out:
# THEFT                               1882
# BATTERY                             1616
# CRIMINAL DAMAGE                     1000
# NARCOTICS                            952
# ASSAULT                              595
# BURGLARY                             532
# OTHER OFFENSE                        526
# MOTOR VEHICLE THEFT                  434
# DECEPTIVE PRACTICE                   352
# ROBBERY                              322
# CRIMINAL TRESPASS                    259
# PROSTITUTION                         121
# WEAPONS VIOLATION                    106
# PUBLIC PEACE VIOLATION                75
# OFFENSE INVOLVING CHILDREN            66
# CRIM SEXUAL ASSAULT                   41
# SEX OFFENSE                           37
# GAMBLING                              22
# LIQUOR LAW VIOLATION                  19
# INTERFERENCE WITH PUBLIC OFFICER      18
# HOMICIDE                              14
# ARSON                                 13
# KIDNAPPING                             9
# ...

# %%
# Top 5 frequency of the Primary type
df['Primary Type'].value_counts().nlargest(5)
# Out:
# THEFT              1882
# BATTERY            1616
# CRIMINAL DAMAGE    1000
# NARCOTICS           952
# ASSAULT             595
# Name: Primary Type, dtype: int64

# %%
# show bar graph
import matplotlib.pyplot as plt
df['Primary Type'].value_counts().plot.bar()

# %%
#plot relative frequency hist graph now to transpone upside down
#It is not need to show
import matplotlib.pyplot as plt
df['Primary Type'].value_counts().plot.hist(x='Distance')
