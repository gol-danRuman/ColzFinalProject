# %%
import pickle

# %%
file = open("../../data/data1000.obj", 'rb')
df = pickle.load(file)
file.close()

# %%
crimes = df['Primary Type']

# %%
my_tags = crimeType = crimes.unique()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,4))

# %%
df['Primary Type'].value_counts().plot(kind='bar');

# %%
plt.figure(figsize=(20, 10))
plt.bar(df['Primary Type'].value_counts().index,df['Primary Type'].value_counts().values, align='center', alpha=0.5)
plt.xticks(df['Primary Type'].value_counts().index, df['Primary Type'].value_counts().index)
plt.ylabel('No. of Crimes')
plt.xlabel('Crimes Names')
plt.xticks(rotation=90)
plt.title('Frequency of Crime Categories')
plt.savefig('CrimeFrequencyBarGraph.png',dpi=100)
plt.show()

# %%
df.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 1  10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 2  10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 3  10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 4  10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#     Primary Type              Description Location Description  Arrest  \
# 0        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 1  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 2        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 3        BATTERY                   SIMPLE            APARTMENT   False
# 4        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
# ...

# %%
df['Year'].value_counts().plot(kind='bar');

# %%
df['Arrest'].value_counts().plot(kind='pie');

# %%
df['Domestic'].value_counts().plot(kind='pie');

# %%
x= df['Year']
y = df['Primary Type']

# %%
# Out:
# 2015

# %%
df.plot(kind='scatter', y = df['Primary Type'].transpose().values.tolist(), x = df['Year'].transpose().values.tolist());
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-712042b62b6e> in <module>
# ----> 1 df.plot(kind='scatter', y = df['Primary Type'].transpose().values.tolist(), x = df['Year'].transpose().values.tolist());
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# ...
